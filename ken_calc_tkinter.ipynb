# %%
"""Made from scratch keep credit do not change anything for education purposes
credit @ken
"""

# Python program to create a simple calc
# calculator using Tkinter
 
# import everything from tkinter module
from tkinter import *
import math
 
# globally declare the my_function variable
#it also makes the setting of the entry to be blank by @ken
my_function = ""
 #function to find tan of a number
 #made by @ ken
def sin_no():
    global my_function
    result=str(math.sin(math.radians(int(my_function))))
    equation.set(result)

#function to find cos
def cos_no():
    global my_fuction
    res=str(math.cos(math.radians(int(my_function))))
    equation.set(res)

# Function to update my_function
# in the text entry box
def press(num):
    # point out the global my_function variable
    global my_function
 
    # concatenation of string
    my_function = my_function + str(num)
 
    # update the my_function by using set method
    equation.set(my_function)
 
 
# Function to evaluate the final my_function
def equalpress():
    # Try and except statement is used
    # for handling the errors like zero
    # division error etc.
 
    # Put that code inside the try block
    # which may generate the error
    try:
 
        global my_function
 
        # eval function evaluate the my_function
        # and str function convert the result
        # into string
        total = str(eval(my_function))
 
        equation.set(total)
 
        # initialize the my_function variable
        # by empty string
        my_function = ""
 
    # if error is generate then handle
    # by the except block
    except:
 
        equation.set(" error ")
        my_function = ""
 
 #made by @ken
# Function to clear the contents
# of text entry box
def clear():
    global my_function
    my_function = ""
    equation.set("")
 #function to find factorial
 #made by @ken
def fact_no():
    global my_function
    fact=str(math.factorial(int(my_function)))
    equation.set(fact)
 	
 #clear number number one by one not at once
#made by @ken
def clear_all():
    global my_function
    text=my_function[:-1]
    my_function=text
    equation.set(text)

#function to create 
#made by@ken
def tan_no():
	global my_function
	tan_num=str(math.tan(math.radians(int(my_function))))
	equation.set(tan_num)
	
#function to find ln
def ln ():
	my_ln=str(math.log(float(my_function)))
	equation.set(my_ln)
	
#function find log
def log_no():
    global my_function
    log_num=str(math.log10(int(my_function)))
    equation.set(log_num)
#function to find the modulus

    # create ken window
ken = Tk()
# set the background colour of ken window
ken.configure(background='black')
 
    # set the title of ken window
ken.title("Simple Calculator")
 
    # set the configuration of ken window
ken.geometry("1366x768")
 
    # StringVar() is the variable class
    # we create an instance of this class
equation = StringVar()
 
    # create the text entry box for
    # showing the my_function .
my_function_field = Entry(ken, textvariable=equation, highlightcolor="red")
 
    # grid method is used for placing
    # the widgets at respective positions
    # in table like structure .
my_function_field.grid(columnspan=12, ipadx=100)
 
    # create a Buttons and place at a particular
    # location inside the root window .
    # when user press the button, the command or
    # function affiliated to that button is executed .
button1 = Button(ken, text=' 1 ', fg='black', bg='white',
                    command=lambda: press(1), height=1, width=7)
button1.grid(row=2, column=0)
 
button2 = Button(ken, text=' 2 ', fg='black', bg='white',
                    command=lambda: press(2), height=1, width=7)
button2.grid(row=2, column=1)
 
button3 = Button(ken, text=' 3 ', fg='black', bg='white',
                    command=lambda: press(3), height=1, width=7)
button3.grid(row=2, column=2)
button4 = Button(ken, text=' 4 ', fg='black', bg='white',
                    command=lambda: press(4), height=1, width=7)
button4.grid(row=3, column=0)
button5 = Button(ken, text=' 5 ', fg='black', bg='white',
                    command=lambda: press(5), height=1, width=7)
button5.grid(row=3, column=1)
 
button6 = Button(ken, text=' 6 ', fg='black', bg='white',
                    command=lambda: press(6), height=1, width=7)
button6.grid(row=3, column=2)
 
button7 = Button(ken, text=' 7 ', fg='black', bg='white',
                    command=lambda: press(7), height=1, width=7)
button7.grid(row=4, column=0)
 
button8 = Button(ken, text=' 8 ', fg='black', bg='white',
                    command=lambda: press(8), height=1, width=7)
button8.grid(row=4, column=1)
 
button9 = Button(ken, text=' 9 ', fg='black', bg='white',
                    command=lambda: press(9), height=1, width=7)
button9.grid(row=4, column=2)
 
button0 = Button(ken, text=' 0 ', fg='black', bg='white',
                    command=lambda: press(0), height=1, width=7)
button0.grid(row=5, column=0)
 
plus = Button(ken, text=' + ', fg='black', bg='white',
                command=lambda: press("+"), height=1, width=7)
plus.grid(row=2, column=3)
 
minus = Button(ken, text=' - ', fg='black', bg='white',
                command=lambda: press("-"), height=1, width=7)
minus.grid(row=3, column=3)
 
multiply = Button(ken, text=' * ', fg='black', bg='white',
                    command=lambda: press("*"), height=1, width=7)
multiply.grid(row=4, column=3)
 
divide = Button(ken, text=' / ', fg='black', bg='white',
                    command=lambda: press("/"), height=1, width=7)
divide.grid(row=5, column=3)
 
equal = Button(ken, text=' = ', fg='black', bg='white',
                command=equalpress, height=1, width=7)
equal.grid(row=5, column=2)
 
clear = Button(ken, text='Clear', fg='black', bg='white',
                command=clear, height=1, width=7)
clear.grid(row=5, column='1')
 
Decimal= Button(ken, text='.', fg='black', bg='white',
                    command=lambda: press('.'), height=1, width=7)
Decimal.grid(row=6, column=0)
tan_button=Button(ken,text='sin(x)',fg='black',bg='white', command=sin_no,height=1,width=7)
tan_button.grid(row=6, column=0)

factorial=Button(ken,text='factorial',fg='black',bg='white',command=fact_no,height=1,width=7)
factorial.grid(row=7,column=0)

delete=Button(ken,text='delete',bg='white',fg='black',command=clear_all,height=1,width=7)
delete.grid(row=6,column=3)

cos_button=Button(ken,text='cos(x)',bg='white',fg='black',command=cos_no, height=1, width=7)
cos_button.grid(row=6,column=2)

tan_num=Button(ken,text='tan(x)',bg='white',fg='black',command=tan_no,height=1,width=7)
tan_num.grid(row=7,column=2)

log_num=Button(ken,text='log(x)',bg='white',fg='black',command=log_no,height=1,width=7)
log_num.grid(row=6,column=1)

pi_button=Button(ken,text="pi",bg='white',fg='black',command=lambda:press(math.pi), height=1,width=7)
pi_button.grid(row=7,column=1)
ln_no=Button(ken,text='ln',bg='white',fg='black',height=1,width=7,command=ln)
ln_no.grid(row=8,column=1)
e=Button(ken,text='e',height=1,width=7,fg='black',bg='white',command=lambda:press(math.e))
e.grid(row=8,column=2)
decimal=Button(ken,text='.',height=1,width=7,command=lambda:press('.'),fg='black',bg='white')
decimal.grid(column=3,row=8)
mod=Button(ken, text="%", height=1, width=7, fg="black", bg="white", command=lambda:press("%")).grid(column=3, row=7)
#sin_ken=Button(ken,text='sin',bg='white',fg='black',command=lambda:press(math.sin(math.radian)))
#sin_ken.grid(row=7,column=3)
    # start&run the ken
ken.mainloop()

# %%
    
"""
  ------------------------------------
   MADE BY @KEN CLOCK HAND
  ------------------------------------
"""
from turtle import *
from datetime import datetime

def jump(distanz, winkel=0):
    penup()
    right(winkel)
    forward(distanz)
    left(winkel)
    pendown()

def hand(laenge, spitze):
    fd(laenge*1.15)
    rt(90)
    fd(spitze/2.0)
    lt(120)
    fd(spitze)
    lt(120)
    fd(spitze)
    lt(120)
    fd(spitze/2.0)

def make_hand_shape(name, laenge, spitze):
    reset()
    jump(-laenge*0.15)
    begin_poly()
    hand(laenge, spitze)
    end_poly()
    hand_form = get_poly()
    register_shape(name, hand_form)

def clockface(radius):
    reset()
    pensize(7)
    for i in range(60):
        jump(radius)
        if i % 5 == 0:
            fd(25)
            jump(-radius-25)
        else:
            dot(3)
            jump(-radius)
        rt(6)

def setup():
    global second_hand, minute_hand, hour_hand, writer
    mode("logo")
    make_hand_shape("second_hand", 125, 25)
    make_hand_shape("minute_hand",  130, 25)
    make_hand_shape("hour_hand", 90, 25)
    clockface(160)
    second_hand = Turtle()
    second_hand.shape("second_hand")
    second_hand.color("gray20", "gray80")
    minute_hand = Turtle()
    minute_hand.shape("minute_hand")
    minute_hand.color("blue1", "red1")
    hour_hand = Turtle()
    hour_hand.shape("hour_hand")
    hour_hand.color("blue3", "red3")
    for hand in second_hand, minute_hand, hour_hand:
        hand.resizemode("user")
        hand.shapesize(1, 1, 3)
        hand.speed(0)
    ht()
    writer = Turtle()
    #writer.mode("logo")
    writer.ht()
    writer.pu()
    writer.bk(85)

def my_days(t):
    my_days = ["Monday", "Tuesday", "Wednesday",
        "Thursday", "Friday", "Saturday", "Sunday"]
    return my_days[t.weekday()]

def datum(z):
    monat = ["Jan.", "Feb.", "Mar.", "Apr.", "May", "June",
             "July", "Aug.", "Sep.", "Oct.", "Nov.", "Dec."]
    j = z.year
    m = monat[z.month - 1]
    t = z.day
    return "%s %d %d" % (m, t, j)

def tick():
    t = datetime.today()
    sekunde = t.second + t.microsecond*0.000001
    minute = t.minute + sekunde/60.0
    stunde = t.hour + minute/60.0
    try:
        tracer(False)  # Terminator can occur here
        writer.clear()
        writer.home()
        writer.forward(65)
       
        writer.write(my_days(t),
                     align="center", font=("Courier", 14, "bold"))
        writer.back(150)
        writer.write(datum(t),
                     align="center", font=("Courier", 14, "bold"))
        writer.forward(85)
        writer.write("Made by @ken",
                     align="center", font=("Courier", 16, "bold"))
        tracer(True)
        second_hand.setheading(6*sekunde)  # or here
        minute_hand.setheading(6*minute)
        hour_hand.setheading(30*stunde)
        tracer(True)
        ontimer(tick, 100)
    except Terminator:
        pass  # turtledemo user pressed STOP

def main():
    tracer(False)
    setup()
    tracer(True)
    tick()
    return "EVENTLOOP"
if __name__=="__main__":
    mode("logo")
    msg = main()
    print(msg)
    mainloop()
# Out:
# EVENTLOOP
